# %%
# !nvidia-smi
# Out:
# Sun Feb  1 16:29:19 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install -q ultralytics opencv-python
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 29.6 MB/s eta 0:00:00

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-a7202efe-133e-4f1d-b0b4-7bdc6cef4122" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a7202efe-133e-4f1d-b0b4-7bdc6cef4122">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

VIDEO_PATH = "vecteezy_image-of-traffic-on-the-road-passing-between-buildings-in_23272130.mov"   # 🔁 change if needed
print("File exists:", os.path.exists(VIDEO_PATH))
# Out:
# File exists: True

# %%
import cv2

cap = cv2.VideoCapture(VIDEO_PATH)
print("Video opened successfully:", cap.isOpened())

fps = cap.get(cv2.CAP_PROP_FPS)
frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print("FPS:", fps, "Frames:", frames)

cap.release()
# Out:
# Video opened successfully: True
# FPS: 23.976023976023978 Frames: 486

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
result = model.predict(
    source=VIDEO_PATH,
    conf=0.4,
    iou=0.5,
    save=True,
    classes=[2, 3, 5, 7],
    device=0
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/486) /content/vecteezy_image-of-traffic-on-the-road-passing-between-buildings-in_23272130.mov: 384x640 11 cars, 76.0ms
# video 1/1 (frame 2/486) /content/vecteezy_image-of-traffic-on-the-road-passing-between-buildings-in_23272130.mov: 384x640 13 cars, 9.6ms
# video 1/1 (frame 3/486) /content/vecteezy_image-of-traffic-on-the-road-passing-between-buildings-in_23272130.mov: 384x640 11 cars, 9.0ms
# ...

# %%
import os

os.listdir("runs/detect")
# Out:
# ['predict']

# %%
from IPython.display import Video

Video("runs/detect/predict/traffic.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="....mp4" type="None">
#  Your browser does not support the video tag.
#  </video>

# %%
model.predict(
    source=VIDEO_PATH,
    conf=0.4,
    save=True,
    save_frames=True,
    classes=[2, 3, 5, 7]
)
# Out:
# WARNING ⚠️
# Inference results will accumulate in RAM unless `stream=True` is passed, which can cause out-of-memory errors for large
# sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/486) /content/vecteezy_image-of-traffic-on-the-road-passing-between-buildings-in_23272130.mov: 384x640 11 cars, 11.6ms
# video 1/1 (frame 2/486) /content/vecteezy_image-of-traffic-on-the-road-passing-between-buildings-in_23272130.mov: 384x640 13 cars, 9.2ms
# video 1/1 (frame 3/486) /content/vecteezy_image-of-traffic-on-the-road-passing-between-buildings-in_23272130.mov: 384x640 11 cars, 9.6ms
# ...
